# %%
import Appro_mh_with_BG_square_with_aberr
# Out:
# C:\Vasilisa\Sphere_new\FPR\mosaic_hits\sphere-2\QGSJET_II\10PeV\500\p\10-20\10-20\mosaic_hits_m01_pro_10PeV_10-20_001_c001
# Processing... 1/6000
# ----DONE----
