# %%
import Average_mass_with_optimization_q1q2.py
# Out:
# model_atmosphere =  m01
# Energy_CR =  10 PeV
# Angle_CR  =  10-20
# h  =  900 m
# Type_particles_CR  =  ['p', 'He', 'N', 'S', 'Fe']
#
# Number of events  p 1681
# Number of events  He 2496
# Number of events  N 1639
# Number of events  S 2499
# Number of events  Fe 1560
# Number of events  p 1677
# Number of events  He 1716
# Number of events  N 1642
# Number of events  S 1629
# Number of events  Fe 1616
# N_samples  10
# Минимальный Rc --  2.508043575233609
# Максимальный Rc --  69.44457891772304
# x 8.12473649406316
# x 6.9200930339685405
# x 6.573221001813542
# x 6.103571832870513
# x 5.591306078301039
# x 8.403928187098382
# x 7.715578688453535
# x 6.552161162716369
# x 6.321656982454944
# x 5.943847033883293
# [array([1, 2]), array([3]), array([4]), array([ 5,  6,  7,  8,  9, 10, 11])]
# C:\Users\2000v\Desktop\shpere-2_mass_method\Sphere-2_result\graphs\m01\q2\10PeV\10-20\900m\aver_mass_optim_q1&q2
# ...
